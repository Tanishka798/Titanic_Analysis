# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df.head() #first 5 rows
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail() #last 5 rows
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.sample() #random row
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 255         1       3  female  29.0      0      2  15.2458        C  Third
#
#        who  adult_male deck embark_town alive  alone
# 255  woman       False  NaN   Cherbourg   yes  False

# %%
sns.scatterplot(df[['fare','age']])
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Least number of passengers acc to gender

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # Least no. of passengers acc to Passenger class

# %%
df['pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='pclass')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
sns.countplot(data=df,x='class',hue='survived')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# # Survived passengers VS Unsurvived passengers

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# # Town from which most no . of passengers embarked

# %%
sns.countplot(data=df, x='embark_town')
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %% [markdown]
# # How Survival rate differ between males and females

# %%
sns.countplot(data=df,x='sex',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # Which passenger class not survived more in number

# %%
sns.countplot(data=df,x='class',hue='survived')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# # Which town embarked passengers survived least in number

# %%
sns.countplot(data=df, x='embark_town', hue='survived')
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %% [markdown]
# # avg fare was high for which gender?

# %%
import numpy as np
sns.barplot(data=df,x='sex',y='fare',ci=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11980\3142323292.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data=df,x='sex',y='fare',ci=False)
# <Axes: xlabel='sex', ylabel='fare'>

# %% [markdown]
# # [Fare  and Survival] Do passengers who paid higher fares have better chance of survival

# %%
sns.barplot(data=df, x='survived', y='fare')
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=df,x='survived',y='fare',ci=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11980\91674030.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data=df,x='survived',y='fare',ci=False)
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.barplot(data=df, x='survived', y='fare',errorbar=('ci',False))
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %% [markdown]
# # Investigate relationship between younger age and survival Are younger passengers more likely to survive?

# %%
sns.barplot(data=df,x='survived',y='age')
# Out:
# <Axes: xlabel='survived', ylabel='age'>
